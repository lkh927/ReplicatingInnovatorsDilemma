# %% [markdown]
# **Imports and set magic**

# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from scipy.io import loadmat
import fun1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
Estate = pd.DataFrame(loadmat('PostEstimation.mat')['State_avg'])
Estate.drop(columns=[3])
Estate.rename(columns={0: 'Old-only', 1: 'Both', 2: 'New-only'}, inplace=True)

# %%
fun1.plot_sim(Estate)

# %%
Estate_3 = pd.DataFrame(loadmat('PostEstimation_3.mat')['State_avg'])
Estate_3.drop(columns=[3])
Estate_3.rename(columns={0: 'Old-only', 1: 'Both', 2: 'New-only'}, inplace=True)

# %%
fun1.plot_sim(Estate_3)
